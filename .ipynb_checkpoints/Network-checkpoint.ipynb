# %% [markdown]
# # Network example
# [Teoría de redes](TeoriaRedes.md)
#
# From: https://programminghistorian.org/lessons/exploring-and-analyzing-network-data-with-python
#
# Graphs are structures that map relations between objects. The objects are referred to as nodes and the connections between them as edges in this tutorial. Note that edges and nodes are commonly referred to by several names that generally mean exactly the same thing:
# ```
# node == vertex == point = entitities
# edge == arc == link = relaciones
# ```
#
# A set of nodes are the list names `[A, B, C]` while the edges are the list relations:
# ```
# [(A,C)
#  (B,A)]
# ```
#
#
# We will work with and __Edge List__ from the general network described in [Networkx help](http://pynetwork.readthedocs.io/en/latest/networkx_load.html#edge-list):
#
# ```python
# [(0, 1, {'weight': 4}),
#  (0, 5, {'weight': 6}),
#  (1, 3, {'weight': 2}),
#  (1, 6, {'weight': 5}),
#  (3, 4, {'weight': 3})]
# ```

# %% [markdown]
# ##  Initialization

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import networkx as nx
import numpy as np

# %%
nd=pd.read_csv( "https://programminghistorian.org/assets/exploring-and-analyzing-network-data-with-python/quakers_nodelist.csv")
ed=pd.read_csv("https://programminghistorian.org/assets/exploring-and-analyzing-network-data-with-python/quakers_edgelist.csv")

# %%
nd[:1]
# Out:
#            Name Historical Significance Gender  Birthdate  Deathdate        ID
# 0  Joseph Wyeth        religious writer   male       1663       1731  10013191

# %%
ed[:1]
# Out:
#          Source          Target
# 0  George Keith  Robert Barclay

# %% [markdown]
# ## Example of conexions

# %% [markdown]
# The DataFrame contents can be filtered by using the Boolean masks of python lists

# %%
cn=ed[np.logical_or(ed.Source=='Peter Collinson',ed.Target=='Peter Collinson')]
cn
# Out:
#              Source        Target
# 10  Peter Collinson  John Bartram
# 11  Peter Collinson   James Logan

# %% [markdown]
# We now append to this DataFrame the full connections of 'John Bartram' and 'John Bartram':

# %%
cn=cn.append(ed[np.logical_or(ed.Source=='John Bartram',ed.Target=='John Bartram')])
cn=cn.append(ed[np.logical_or(ed.Source=='James Logan',ed.Target=='James Logan')])

# %%
cn
# Out:
#               Source        Target
# 10   Peter Collinson  John Bartram
# 11   Peter Collinson   James Logan
# 10   Peter Collinson  John Bartram
# 110      James Logan  John Bartram
# 11   Peter Collinson   James Logan
# 110      James Logan  John Bartram
# 111      James Logan  William Penn
# 112      James Logan   David Lloyd

# %% [markdown]
# To remove duplicated entries we use:

# %%
cn.drop_duplicates().sort_values('Source')
# Out:
#               Source        Target
# 110      James Logan  John Bartram
# 111      James Logan  William Penn
# 112      James Logan   David Lloyd
# 10   Peter Collinson  John Bartram
# 11   Peter Collinson   James Logan

# %% [markdown]
# The resulting network is

# %% [markdown]
# ```
# William   David
#  \        /
#   \      /
#    \    /
#    James
#    /   \
#   /     \
#  /       \
# Peter--- John
# ```

# %%
nd.Name.shape
# Out:
# (119,)

# %%
ed.shape
# Out:
# (174, 2)

# %% [markdown]
# ##  Build the network

# %%
G=nx.Graph()
G

# %% [markdown]
# ## Node list

# %%
G.add_nodes_from(nd.Name.values)
G

# %% [markdown]
# ## Edge list
# Convert edges in a list of tuples

# %%
tuple_list=(ed.Source+'::'+ed.Target).str.split('::').map(tuple).values

# %%
len(tuple_list)
# Out:
# 174

# %%
G.add_edges_from(tuple_list)

# %%
print( nx.info(G) )
# Out:
# Name:
# Type: Graph
# Number of nodes: 119
# Number of edges: 174
# Average degree:   2.9244

# %% [markdown]
# ## Adding attributes
# https://programminghistorian.org/lessons/exploring-and-analyzing-network-data-with-python#adding-attributes
#
# For NetworkX, a Graph object is one big thing (your network) made up of two kinds of smaller things (your nodes and your edges). So far you’ve uploaded nodes and edges (as pairs of nodes), but NetworkX allows you to add attributes to both nodes and edges, providing more information about each of them. Later on in this tutorial, you’ll be running metrics and adding some of the results back to the Graph as attributes. For now, let’s make sure your Graph contains all of the attributes that are currently in our CSV.
#
# You’ll want to return to a list you created at the beginning of your script: nodes. This list contains all of the rows from quakers_nodelist.csv, including columns for name, historical significance, gender, birth year, death year, and SDFB ID. You’ll want to loop through this list and add this information to our graph. There are a couple ways to do this, but NetworkX provides two convenient functions for adding attributes to all of a Graph’s nodes or edges at once: nx.set_node_attributes() and nx.set_edge_attributes(). To use these functions, you’ll need your attribute data to be in the form of a Python dictionary, in which node names are the keys and the attributes you want to add are the values.5 You’ll want to create a dictionary for each one of your attributes, and then add them using the functions above. The first thing you must do is create five empty dictionaries, using curly braces:

# %% [markdown]
# Each dictionary is obtained from a `Series` like
#
# See https://stackoverflow.com/a/17426500/2268280

# %%
nd.Name
# Out:
# 0                    Joseph Wyeth
# 1      Alexander Skene of Newtyle
# 2                     James Logan
# 3                   Dorcas Erbery
# 4                    Lilias Skene
# 5                 William Mucklow
# 6                Thomas Salthouse
# 7                William Dewsbury
# 8                    John Audland
# 9                Richard Claridge
# 10               William Bradford
# 11             Fettiplace Bellers
# 12                   John Bellers
# 13                 Isabel Yeamans
# 14         George Fox the younger
# 15                     George Fox
# 16                    John Stubbs
# 17                      Anne Camm
# 18                      John Camm
# 19                    Thomas Camm
# 20                Katharine Evans
# 21                Lydia Lancaster
# 22               Samuel Clarridge
# 23                   Thomas Lower
# 24                 Gervase Benson
# 25                  Stephen Crisp
# 26                James Claypoole
# 27                   Thomas Holme
# 28                    John Freame
# 29                   John Swinton
#                   ...
# 89                   John Bartram
# 90               Edward Haistwell
# 91                   John ap John
# 92                      John Rous
# 93                Anthony Pearson
# 94                 Solomon Eccles
# 95                  John Burnyeat
# 96                Edward Burrough
# 97                Rebecca Travers
# 98              William Edmundson
# 99                 Sarah Cheevers
# 100                  Edward Pyott
# 101                  Daniel Quare
# 102                John Penington
# 103                Mary Penington
# 104              Charles Marshall
# 105             Humphrey Woolrich
# 106                  William Penn
# 107                 Mary Pennyman
# 108                 Dorothy Waugh
# 109                   David Lloyd
# 110                  Lewis Morris
# 111               Martha Simmonds
# 112                    John Story
# 113                  Thomas Story
# 114                Thomas Ellwood
# 115               William Simpson
# 116                 Samuel Bownas
# 117                   John Perrot
# 118               Hannah Stranger
# Name: Name, dtype: object

# %%
pd.Series(nd.ID.values,index=nd.Name)[:2]
# Out:
# Name
# Joseph Wyeth                  10013191
# Alexander Skene of Newtyle    10011149
# dtype: int64

# %%
hist_sig_dict=pd.Series(nd['Historical Significance'].values,index=nd.Name).to_dict()
gender_dict=pd.Series(nd["Gender"].values,index=nd.Name).to_dict()
birth_dict=pd.Series(nd["Birthdate"].values,index=nd.Name).to_dict()
death_dict=pd.Series(nd["Deathdate"].values,index=nd.Name).to_dict()
id_dict=pd.Series(nd["ID"].values,index=nd.Name).to_dict()

gender_dict
# Out:
# {'Alexander Parker': 'male',
#  'Alexander Skene of Newtyle': 'male',
#  'Alice Curwen': 'female',
#  'Anne Camm': 'female',
#  'Anne Conway Viscountess Conway and Killultagh': 'female',
#  'Anthony Pearson': 'male',
#  'Anthony Sharp': 'male',
#  'Benjamin Furly': 'male',
#  'Charles Marshall': 'male',
#  'Christopher Taylor': 'male',
#  'Daniel Quare': 'male',
#  'David Barclay': 'male',
#  'David Barclay of Ury': 'male',
#  'David Lloyd': 'male',
#  'Dorcas Erbery': 'female',
#  'Dorothy Waugh': 'female',
#  'Edward Burrough': 'male',
#  'Edward Haistwell': 'male',
#  'Edward Pyott': 'male',
#  'Elizabeth Hooten': 'female',
#  'Elizabeth Leavens': 'female',
#  'Ellis Hookes': 'male',
#  'Fettiplace Bellers': 'male',
#  'Francis Bugg': 'male',
#  'Francis Howgill': 'male',
#  'Franciscus Mercurius van Helmont': 'male',
#  'George Bishop': 'male',
#  'George Fox': 'male',
#  'George Fox the younger': 'male',
#  'George Keith': 'male',
#  'George Whitehead': 'male',
#  'Gervase Benson': 'male',
#  'Gideon Wanton': 'male',
#  'Gilbert Latey': 'male',
#  'Grace Chamber': 'female',
#  'Hannah Stranger': 'female',
#  'Henry Pickworth': 'male',
#  'Humphrey Norton': 'male',
#  'Humphrey Woolrich': 'male',
#  'Isaac Norris': 'male',
#  'Isabel Yeamans': 'female',
#  'James Claypoole': 'male',
#  'James Logan': 'male',
#  'James Nayler': 'male',
#  'James Parnel': 'male',
#  'Jane Sowle': 'female',
#  'John Audland': 'male',
#  'John Bartram': 'male',
#  'John Bellers': 'male',
#  'John Burnyeat': 'male',
#  'John Camm': 'male',
#  'John Crook': 'male',
#  'John Freame': 'male',
#  'John Penington': 'male',
#  'John Perrot': 'male',
#  'John Rous': 'male',
#  'John Story': 'male',
#  'John Stubbs': 'male',
#  'John Swinton': 'male',
#  'John Wanton': 'male',
#  'John Whitehead': 'male',
#  'John Whiting': 'male',
#  'John Wilkinson': 'male',
#  'John ap John': 'male',
#  'Joseph Besse': 'male',
#  'Joseph Wyeth': 'male',
#  'Katharine Evans': 'female',
#  'Leonard Fell': 'male',
#  'Lewis Morris': 'male',
#  'Lilias Skene': 'male',
#  'Lydia Lancaster': 'female',
#  'Margaret Fell': 'female',
#  'Martha Simmonds': 'female',
#  'Mary Fisher': 'female',
#  'Mary Penington': 'female',
#  'Mary Pennyman': 'female',
#  'Mary Prince': 'female',
#  'Peter Collinson': 'male',
#  'Rebecca Travers': 'female',
#  'Richard Claridge': 'male',
#  'Richard Farnworth': 'male',
#  'Richard Hubberthorne': 'male',
#  'Richard Vickris': 'male',
#  'Robert Barclay': 'male',
#  'Robert Rich': 'male',
#  'Samuel Bownas': 'male',
#  'Samuel Clarridge': 'male',
#  'Samuel Fisher': 'male',
#  'Sarah Cheevers': 'female',
#  'Sarah Gibbons': 'female',
#  'Silvanus Bevan': 'male',
#  'Sir Charles Wager': 'male',
#  'Solomon Eccles': 'male',
#  'Stephen Crisp': 'male',
#  'Tace Sowle': 'male',
#  'Thomas Aldam': 'male',
#  'Thomas Camm': 'male',
#  'Thomas Curtis': 'male',
#  'Thomas Ellwood': 'male',
#  'Thomas Holme': 'male',
#  'Thomas Lawson': 'male',
#  'Thomas Lower': 'male',
#  'Thomas Salthouse': 'male',
#  'Thomas Story': 'male',
#  'Thomas Taylor': 'male',
#  'William Ames': 'male',
#  'William Bradford': 'male',
#  'William Caton': 'male',
#  'William Coddington': 'male',
#  'William Crouch': 'male',
#  'William Dewsbury': 'male',
#  'William Edmundson': 'male',
#  'William Gibson': 'male',
#  'William Mead': 'male',
#  'William Mucklow': 'male',
#  'William Penn': 'male',
#  'William Rogers': 'male',
#  'William Simpson': 'male',
#  'William Tomlinson': 'male'}

# %% [markdown]
# ### Visualization Layouts
# http://pynetwork.readthedocs.io/en/latest/networkx_draw.html

# %%
ps=[nx.circular_layout(G),
 nx.random_layout(G),
 nx.shell_layout(G),
 nx.spring_layout(G),
 nx.spectral_layout(G),
 nx.fruchterman_reingold_layout(G)]

# %%
plt.figure(figsize=(20, 20))

# chose the layout
pos=ps[5]
nx.draw_networkx(G, pos, with_labels = True, node_size=50, node_color='red', \
                         alpha=0.7, edge_color='grey', width=1)

# %% [markdown]
# ![IMG](https://programminghistorian.org/images/exploring-and-analyzing-network-data-with-python/exploring-and-analyzing-network-data-with-python-1.png)

# %% [markdown]
# Return back to [Pandas](./Pandas.ipynb#Conclusion)

# %% [markdown]
# __Activity__: Extract some nodes of the network associated to 'William Penn' from the original 'ed' DataFrame

# %%
hc=ed[np.logical_or(ed.Source=='William Penn',ed.Target=='William Penn')]
hc
# Out:
#                Source            Target
# 4        George Keith      William Penn
# 32   William Bradford      William Penn
# 39     Isabel Yeamans      William Penn
# 57         George Fox      William Penn
# 71       Isaac Norris      William Penn
# 109    Benjamin Furly      William Penn
# 111       James Logan      William Penn
# 114  Edward Haistwell      William Penn
# 127  George Whitehead      William Penn
# 134     John Burnyeat      William Penn
# 141   Rebecca Travers      William Penn
# 151      William Penn        Tace Sowle
# 152      William Penn   James Claypoole
# 153      William Penn      Thomas Story
# 154      William Penn    Mary Penington
# 155      William Penn       David Lloyd
# 156      William Penn     Margaret Fell
# 157      William Penn  Richard Claridge

# %%
hc=hc.append(ed[np.logical_or(ed.Source=='George Keith',ed.Target=='George Keith')])
hc.drop_duplicates().sort_values('Source')
hc
# Out:
#                Source                                         Target
# 4        George Keith                                   William Penn
# 32   William Bradford                                   William Penn
# 39     Isabel Yeamans                                   William Penn
# 57         George Fox                                   William Penn
# 71       Isaac Norris                                   William Penn
# 109    Benjamin Furly                                   William Penn
# 111       James Logan                                   William Penn
# 114  Edward Haistwell                                   William Penn
# 127  George Whitehead                                   William Penn
# 134     John Burnyeat                                   William Penn
# 141   Rebecca Travers                                   William Penn
# 151      William Penn                                     Tace Sowle
# 152      William Penn                                James Claypoole
# 153      William Penn                                   Thomas Story
# 154      William Penn                                 Mary Penington
# 155      William Penn                                    David Lloyd
# 156      William Penn                                  Margaret Fell
# 157      William Penn                               Richard Claridge
# 0        George Keith                                 Robert Barclay
# 1        George Keith                                 Benjamin Furly
# 2        George Keith  Anne Conway Viscountess Conway and Killultagh
# 3        George Keith               Franciscus Mercurius van Helmont
# 4        George Keith                                   William Penn
# 5        George Keith                                     George Fox
# 6        George Keith                               George Whitehead
# 7        George Keith                               William Bradford

# %%
tuple_list=(hc.Source+'::'+hc.Target).str.split('::').map(tuple).values
tuple_list[:2]
# Out:
# array([('George Keith', 'William Penn'),
#        ('William Bradford', 'William Penn')], dtype=object)

# %%
G=nx.Graph()
G.add_nodes_from(nd.Name.values)
G.add_edges_from(tuple_list)
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 119
# Number of edges: 25
# Average degree:   0.4202

# %%
pd.Series(nd.ID.values, index=nd.Name)[:2]
# Out:
# Name
# Joseph Wyeth                  10013191
# Alexander Skene of Newtyle    10011149
# dtype: int64

# %%
hist_sig_dict=pd.Series(nd["Historical Significance"].values,index=nd.Name).to_dict()
gender_dict=pd.Series(nd["Gender"].values,index=nd.Name).to_dict()
birth_dict=pd.Series(nd["Birthdate"].values,index=nd.Name).to_dict()
death_dict=pd.Series(nd["Deathdate"].values,index=nd.Name).to_dict()
id_dict=pd.Series(nd["ID"].values,index=nd.Name).to_dict()

# %%
plt.figure(figsize=(25, 25))

nx.draw_networkx(G, with_labels = True, node_size=100, node_color='green', \
                         alpha=0.7, edge_color='grey', width=1)

# %% [markdown]
# ## Appendix

# %% [markdown]
# Manipulating edges with attributes

# %%
df=pd.DataFrame( {'name1': ['Georgia','Georgia','Lee'], 
                  'name2': ['Lee','Claude','Claude'],
                  'weights':[{u'Weight': 10},{u'Weight': 90},{u'Weight': 0}]} )
df
# Out:
#      name1   name2         weights
# 0  Georgia     Lee  {'Weight': 10}
# 1  Georgia  Claude  {'Weight': 90}
# 2      Lee  Claude   {'Weight': 0}

# %%
df['relation'] = df['weights'].map(lambda x: x['Weight'])

# %%
df
# Out:
#      name1   name2         weights  relation
# 0  Georgia     Lee  {'Weight': 10}        10
# 1  Georgia  Claude  {'Weight': 90}        90
# 2      Lee  Claude   {'Weight': 0}         0
